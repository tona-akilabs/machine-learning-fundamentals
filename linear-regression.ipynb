# %%
pip install numpy pandas scikit-learn matplotlib
# Out:
# Requirement already satisfied: numpy in c:\users\rachh\appdata\local\programs\python\python313\lib\site-packages (2.3.0)
# Requirement already satisfied: pandas in c:\users\rachh\appdata\local\programs\python\python313\lib\site-packages (2.3.0)
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp313-cp313-win_amd64.whl.metadata (52 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rachh\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rachh\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rachh\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.0-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp313-cp313-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\rachh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in c:\users\rachh\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading scikit_learn-1.8.0-cp313-cp313-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    --------- ------------------------------ 1.8/8.0 MB 10.2 MB/s eta 0:00:01
#    -------------------- ------------------- 4.2/8.0 MB 10.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.0 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 9.4 MB/s eta 0:00:00
# Downloading matplotlib-3.10.8-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----------- ---------------------------- 2.4/8.1 MB 12.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 10.8 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------------------------------ --- 2.1/2.3 MB 12.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 10.2 MB/s eta 0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl (73 kB)
# Downloading pillow-12.1.0-cp313-cp313-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    -------------- ------------------------- 2.6/7.0 MB 13.5 MB/s eta 0:00:01
#    -------------------------- ------------- 4.7/7.0 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 11.6 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading scipy-1.17.0-cp313-cp313-win_amd64.whl (36.3 MB)
#    ---------------------------------------- 0.0/36.3 MB ? eta -:--:--
#    -- ------------------------------------- 2.1/36.3 MB 11.6 MB/s eta 0:00:03
#    ---- ----------------------------------- 3.7/36.3 MB 9.5 MB/s eta 0:00:04
#    ----- ---------------------------------- 4.7/36.3 MB 7.9 MB/s eta 0:00:05
#    ------- -------------------------------- 6.6/36.3 MB 7.9 MB/s eta 0:00:04
#    -------- ------------------------------- 7.9/36.3 MB 7.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 9.2/36.3 MB 7.3 MB/s eta 0:00:04
#    ----------- ---------------------------- 10.2/36.3 MB 7.2 MB/s eta 0:00:04
#    ------------ --------------------------- 11.3/36.3 MB 6.8 MB/s eta 0:00:04
#    ------------- -------------------------- 12.6/36.3 MB 6.7 MB/s eta 0:00:04
#    --------------- ------------------------ 13.9/36.3 MB 6.7 MB/s eta 0:00:04
#    ---------------- ----------------------- 15.2/36.3 MB 6.7 MB/s eta 0:00:04
#    ------------------ --------------------- 16.5/36.3 MB 6.7 MB/s eta 0:00:03
#    ------------------- -------------------- 18.1/36.3 MB 6.7 MB/s eta 0:00:03
#    --------------------- ------------------ 19.1/36.3 MB 6.6 MB/s eta 0:00:03
#    ---------------------- ----------------- 20.2/36.3 MB 6.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 21.2/36.3 MB 6.4 MB/s eta 0:00:03
#    ------------------------ --------------- 22.3/36.3 MB 6.3 MB/s eta 0:00:03
#    ------------------------- -------------- 23.3/36.3 MB 6.3 MB/s eta 0:00:03
#    -------------------------- ------------- 24.4/36.3 MB 6.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 25.7/36.3 MB 6.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 26.7/36.3 MB 6.2 MB/s eta 0:00:02
#    ------------------------------ --------- 28.0/36.3 MB 6.2 MB/s eta 0:00:02
#    -------------------------------- ------- 29.4/36.3 MB 6.1 MB/s eta 0:00:02
#    --------------------------------- ------ 30.7/36.3 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 31.7/36.3 MB 6.1 MB/s eta 0:00:01
#    ------------------------------------ --- 32.8/36.3 MB 6.1 MB/s eta 0:00:01
#    ------------------------------------- -- 34.1/36.3 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------  35.4/36.3 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------  36.2/36.3 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 36.3/36.3 MB 5.9 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, pyparsing, pillow, kiwisolver, joblib, fonttools, cycler, contourpy, scikit-learn, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 joblib-1.5.3 kiwisolver-1.4.9 matplotlib-3.10.8 pillow-12.1.0 pyparsing-3.3.2 scikit-learn-1.8.0 scipy-1.17.0 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\rachh\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: C:\Users\rachh\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
# Input (X) and Output (y)
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)  # must be 2D
y = np.array([50, 55, 65, 70, 75])

# %% [markdown]
# Create the Linear Regression model

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# View the learned equation

# %%
m = model.coef_[0]
b = model.intercept_

print(f"Slope (m): {m}")
print(f"Intercept (b): {b}")
# Out:
# Slope (m): 6.500000000000001
# Intercept (b): 43.5

# %% [markdown]
# So the equation is:
#
#          y=6.5x + 43.5

# %% [markdown]
# Make a prediction

# %%
prediction = model.predict([[6]])
print("Predicted score:", prediction[0])
# Out:
# Predicted score: 82.5

# %% [markdown]
# Scikit-learn computes:
#
#     y^=m⋅x+b
#
# Substitute values:
#
#     y^=6.5×6+43.5
#
# Calculate step by step:
#
#     6.5×6=39
#
#     39+43.5=82.5

# %% [markdown]
# Visualize the result

# %%
# Plot data points
plt.scatter(X, y)

# Plot regression line
plt.plot(X, model.predict(X))

plt.xlabel("Study Hours")
plt.ylabel("Exam Score")
plt.title("Linear Regression Example")
plt.show()
