# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
import matplotlib.pyplot as plt

# %% [markdown]
# Classification with KNN (K-Nearest Neighbors)

# %%
# Dataset
X = np.array([
    [25, 30],
    [30, 40],
    [35, 60],
    [40, 80],
    [50, 100]
])

y = np.array([0, 0, 1, 1, 1])  # 0 = No, 1 = Yes

# Model (K = 3)
knn = KNeighborsClassifier(n_neighbors=3)

# Train
knn.fit(X, y)

# Predict new person: Age = 33, Salary = 50k
new_person = np.array([[33, 50]])
prediction = knn.predict(new_person)

print("Prediction:", "Yes" if prediction[0] == 1 else "No")
# Out:
# Prediction: No

# %% [markdown]
# Visualization

# %%
# Create grid for decision boundary
x_min, x_max = 20, 55
y_min, y_max = 20, 110
xx, yy = np.meshgrid(
    np.linspace(x_min, x_max, 200),
    np.linspace(y_min, y_max, 200)
)

Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plot decision boundary
plt.contourf(xx, yy, Z, alpha=0.4)

# Plot points
plt.scatter(X[y == 0][:, 0], X[y == 0][:, 1], label="No")
plt.scatter(X[y == 1][:, 0], X[y == 1][:, 1], label="Yes")

# New point
# Predict new persons:
# Age = 33, Salary = 50k
# Age = 36, Salary = 65k
new_point = np.array([[33, 50], [36, 65]])
plt.scatter(new_point[:, 0], new_point[:, 1], marker="x", s=50, label="New")

plt.xlabel("Age")
plt.ylabel("Salary")
plt.legend()
plt.title("KNN Classification (K=3)")
plt.show()

# %% [markdown]
# Regression with KNN

# %%
# Simple dataset
X = np.array([[1], [2], [3], [4], [5], [6]])
y = np.array([10, 20, 30, 40, 50, 60])

# Model
knn_reg = KNeighborsRegressor(n_neighbors=2)
knn_reg.fit(X, y)
# Out:
# KNeighborsRegressor(n_neighbors=2)

# %%
# Predict
print(knn_reg.predict([[2.5]]))
# Out:
# [25.]

# %% [markdown]
# Visualization

# %%
# Predict on many points for smooth curve
X_test = np.linspace(0, 6, 150).reshape(-1, 1)
print(X_test)
y_pred = knn_reg.predict(X_test)

# Plot original data
plt.scatter(X, y, label="Data")

# Plot prediction curve
plt.plot(X_test, y_pred, label="KNN Prediction")

# Highlight prediction at x=2.5, x=3.5, x=4.5
x_new = np.array([[2.5], [3.5], [4.5]])
y_new = knn_reg.predict(x_new)

plt.scatter(x_new, y_new, marker="x", s=100, label="Prediction")

plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.title("KNN Regression (K=2)")
plt.show()
# Out:
# [[0.        ]
#  [0.04026846]
#  [0.08053691]
#  [0.12080537]
#  [0.16107383]
#  [0.20134228]
#  [0.24161074]
#  [0.28187919]
#  [0.32214765]
#  [0.36241611]
#  [0.40268456]
#  [0.44295302]
#  [0.48322148]
#  [0.52348993]
#  [0.56375839]
#  [0.60402685]
#  [0.6442953 ]
#  [0.68456376]
#  [0.72483221]
#  [0.76510067]
#  [0.80536913]
#  [0.84563758]
#  [0.88590604]
#  [0.9261745 ]
#  [0.96644295]
#  [1.00671141]
#  [1.04697987]
#  [1.08724832]
#  [1.12751678]
#  [1.16778523]
#  [1.20805369]
#  [1.24832215]
#  [1.2885906 ]
#  [1.32885906]
#  [1.36912752]
#  [1.40939597]
#  [1.44966443]
#  [1.48993289]
#  [1.53020134]
#  [1.5704698 ]
#  [1.61073826]
#  [1.65100671]
#  [1.69127517]
#  [1.73154362]
#  [1.77181208]
#  [1.81208054]
#  [1.85234899]
#  [1.89261745]
#  [1.93288591]
#  [1.97315436]
#  [2.01342282]
#  [2.05369128]
#  [2.09395973]
#  [2.13422819]
#  [2.17449664]
#  [2.2147651 ]
#  [2.25503356]
#  [2.29530201]
#  [2.33557047]
#  [2.37583893]
#  [2.41610738]
#  [2.45637584]
# ...
